# %%
import numpy as np
import pandas as pd
import pylab
import seaborn as sns

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.pyplot import subplots
import statsmodels.api as sm
from statsmodels.formula.api import logit

# %matplotlib inline

np.set_printoptions(precision=5, suppress= True)

from google.colab import drive
drive.mount('/content/drive/',force_remount=True)
mydir = "/content/drive/My Drive/Courses/25_1st_Statistical Learning/HW/"
# !ls "/content/drive/My Drive/Courses/25_1st_Statistical Learning/HW/"
# Out:
# Mounted at /content/drive/
#  Auto.csv		     'Mod_stock(Bitcoin).csv'
#  BirdCancer.csv		      Mod_stock.csv
#  cars.csv		     'Mod_stock(gold).csv'
# 'Commodity10(Beef).csv'      'Mod_US Stock Market Dataset_2.csv'
# 'Commodity10(Crudeoil).csv'  'Mod_US Stock Market Dataset.csv'
# 'Commodity2_10(Beef).csv'     NYSE.csv
# 'Commodity(Crudeoil).csv'     pendigits.tra
#  FEV.csv		      Pima.csv
#  Hitters1.csv		      Prob4-2.csv
#  Hw1.ipynb		      Project_Stock_Diff.ipynb
#  HW1_SS.ipynb		      Project_Stock.ipynb
#  HW2_SS.ipynb		      Project_Stock_MA_useless.ipynb
#  HW3_SS.ipynb		      Project_Stock_Mult.ipynb
#  HW4_SS.ipynb		      Project_Stock_MV.ipynb
#  HW5_SS.ipynb		      Project_Stock_original.ipynb
#  HW6_SS.ipynb		      Project_Stock_Univ_bias.ipynb
#  HW7_2_SS.ipynb		      Project_Stock_Univ.ipynb
#  HW7_SS.ipynb		      Sev_temp4.csv
#  HW8_SS.ipynb		     'US Stock Market Dataset.csv'
# 'Mod_stock2_100(tesla).csv'   Xdata.pkl
# 'Mod_stock7(Tesla).csv'       ydata.pkl

# %% [markdown]
# # RNN_multivariate (stock)

# %%
# multivariate only using Tesla stock and filtered Crude_oil

St_data_ori = pd.read_csv(mydir + 'Mod_US Stock Market Dataset_2.csv')
St_data = St_data_ori[::-1].reset_index(drop=True)
dataM_raw = St_data.drop(['No','Date'], axis=1).astype('float64')
print(dataM_raw)
dataM_raw = dataM_raw[['Tesla']]  #bad: , good: , 'Bitcoin' ,'Crude_oil'(loss: 0.0070 - val_loss: 0.0297),'S&P_500'(loss: 0.0079 - val_loss: 0.0100),'Gold'(loss: 0.0232 - val_loss: 0.0309), Not tested: ,
Target_IDX = dataM_raw.columns.get_loc("Tesla")

dataM_Unscale = dataM_raw.to_numpy()
# since each variable is on its own scale, it's a good idea to scale them first

from sklearn.preprocessing import StandardScaler
scalerM = StandardScaler()
dataM = scalerM.fit_transform(dataM_raw)
Start_Time = 0
Cur_Time = 517
Size_data = dataM.shape[1]

# autocorrelation function for the data
#from statsmodels.graphics.tsaplots import plot_acf

#fig, ax = plt.subplots(figsize=(10, 5))
#plot_acf(dataM_past, lags=300, ax=ax, title='Autocorrelation Function') # lags: number of lags to show

#plt.xlabel('Lag')
#plt.ylabel('Autocorrelation')
#plt.show()
# Out:
#      Natural_Gas  Natural_Gas_Vol.  Crude_oil  Crude_oil_Vol.  Copper  \
# 0          2.122          164570.0      61.18        486870.0  2.8250
# 1          2.130          144670.0      63.05        885860.0  2.7870
# 2          2.135          154680.0      63.27        724240.0  2.7900
# 3          2.162          163010.0      62.70        582650.0  2.7935
# 4          2.141          242560.0      59.61       1210000.0  2.8120
# ..           ...               ...        ...             ...     ...
# 713        6.779           73120.0      80.95        269620.0  3.6165
# 714        7.308           59050.0      77.94        379150.0  3.6200
# 715        7.024           35510.0      76.28        266450.0  3.6330
# 716        6.712            3650.0      77.24        405030.0  3.6165
# 717        7.235          101680.0      78.20        381870.0  3.6395
#
#      Copper_Vol.  Bitcoin  Bitcoin_Vol.  Ethereum  Ethereum_Vol.  ...  \
# 0        72460.0   6967.0      632780.0    127.19     11450000.0  ...
# 1        74750.0   7343.0      936290.0    134.27     15670000.0  ...
# 2        59570.0   7759.0      786750.0    144.08     14360000.0  ...
# 3        59470.0   8156.0     1010000.0    143.04     13580000.0  ...
# 4        77700.0   8060.0     1190000.0    140.81     13710000.0  ...
# ..           ...      ...           ...       ...            ...  ...
# 713        250.0  16213.0      287210.0   1139.74       815180.0  ...
# 714        210.0  16624.0      305080.0   1185.79       688960.0  ...
# 715        180.0  16512.0      204070.0   1198.12       426960.0  ...
# 716        460.0  16212.0      284840.0   1167.73       518170.0  ...
# 717      55240.0  16440.0      271580.0   1216.55       549930.0  ...
#
#      Berkshire  Berkshire_Vol.  Netflix  Netflix_Vol.  Amazon  Amazon_Vol.  \
# 0     342261.0           410.0   329.81     4350000.0   94.90   80720000.0
# 1     339155.0           220.0   325.90     3800000.0   93.75   75330000.0
# 2     340210.0           280.0   335.83     5670000.0   95.14   81310000.0
# 3     338901.0           280.0   330.75     4740000.0   95.34   82680000.0
# 4     339188.0           190.0   339.26     7110000.0   94.60   70240000.0
# ..         ...             ...      ...           ...     ...          ...
# 713   476980.0          2820.0   286.69     6250000.0   93.20   62190000.0
# 714   477020.0          2920.0   291.50     5920000.0   94.13   59410000.0
# 715   478676.0          2660.0   285.54     3240000.0   93.41   35090000.0
# 716   472712.0          4030.0   281.17     4710000.0   93.95   75060000.0
# 717   475843.0          2640.0   280.96     5790000.0   92.42   65570000.0
#
#        Meta   Meta_Vol.    Gold  Gold_Vol.
# 0    209.78  12090000.0  1528.1   270550.0
# 1    208.67  11200000.0  1552.4   436740.0
# 2    212.60  17070000.0  1568.8   558970.0
# 3    213.06  15110000.0  1574.3   435870.0
# 4    215.22  13490000.0  1560.2   813410.0
# ..      ...         ...     ...        ...
# 713  111.44  29030000.0  1739.9   153090.0
# 714  112.24  21340000.0  1745.6   167770.0
# 715  111.41  12010000.0  1754.0   134300.0
# 716  108.78  23300000.0  1740.3   132770.0
# 717  109.46  23900000.0  1763.7   127320.0
#
# [718 rows x 35 columns]

# %%
# Create sequences for training
TIME_STEPS = 50
def create_sequences(dataM, time_steps):
    XM, yM = [], []
    for i in range(len(dataM) - time_steps):
        XM.append(dataM[i:i + time_steps])
        yM.append(dataM[i + time_steps])
    return np.array(XM), np.array(yM)

XM, yM = create_sequences(dataM, TIME_STEPS)

XM_past = XM[Start_Time:Cur_Time,:].reshape(-1, TIME_STEPS, Size_data)
yM_past = yM[Start_Time:Cur_Time,:]
XM_future = XM[Cur_Time+1:,:].reshape(-1, TIME_STEPS, Size_data)
yM_future = yM[Cur_Time:,:]

print(XM_past)

XM_Unscale, yM_Unscale = create_sequences(dataM_Unscale, TIME_STEPS)

XM_past_Unscale = XM_Unscale[Start_Time:Cur_Time,:].reshape(-1, TIME_STEPS, Size_data)
yM_past_Unscale = yM_Unscale[Start_Time:Cur_Time,:]
XM_future_Unscale = XM_Unscale[Cur_Time+1:,:].reshape(-1, TIME_STEPS, Size_data)
yM_future_Unscale = yM_Unscale[Cur_Time:,:]
# Out:
# [[[-1.84389]
#   [-1.83512]
#   [-1.82925]
#   ...
#   [-1.70362]
#   [-1.75426]
#   [-1.76385]]
#
#  [[-1.83512]
#   [-1.82925]
#   [-1.81718]
#   ...
#   [-1.75426]
#   [-1.76385]
#   [-1.83368]]
#
#  [[-1.82925]
#   [-1.81718]
#   [-1.80129]
#   ...
#   [-1.76385]
#   [-1.83368]
#   [-1.84389]]
#
#  ...
#
#  [[ 1.06198]
#   [ 0.974  ]
#   [ 0.92408]
#   ...
#   [ 1.21555]
#   [ 1.25341]
#   [ 1.37522]]
#
#  [[ 0.974  ]
#   [ 0.92408]
#   [ 1.03465]
#   ...
#   [ 1.25341]
#   [ 1.37522]
#   [ 1.2467 ]]
#
#  [[ 0.92408]
#   [ 1.03465]
#   [ 0.97978]
#   ...
#   [ 1.37522]
#   [ 1.2467 ]
#   [ 1.31302]]]

# %%
from sklearn.model_selection import train_test_split

XM_train, XM_test, yM_train, yM_test = train_test_split(XM_past, yM_past, random_state=111, test_size = 0.3) # random_state i is a fixed seed value that ensures the random operations (like data shuffling) produce the same result every time.

print(XM_train.shape)

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
# Out:
# (361, 50, 1)

# %%
modelM = Sequential([
    SimpleRNN(50, activation='relu', return_sequences=False),
    Dense(Size_data)  # Output layer for regression (predicting 3 values at once?)
])

modelM.compile(optimizer='adam', loss='mse')
history = modelM.fit(XM_train, yM_train, epochs=200, batch_size=256, validation_data=(XM_test, yM_test))
# Out:
# Epoch 1/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 364ms/step - loss: 1.2660 - val_loss: 0.9976
# Epoch 2/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 1.0160 - val_loss: 0.8193
# Epoch 3/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.8661 - val_loss: 0.6848
# Epoch 4/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 0.7149 - val_loss: 0.5616
# Epoch 5/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.5833 - val_loss: 0.4456
# Epoch 6/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.4821 - val_loss: 0.3449
# Epoch 7/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.3686 - val_loss: 0.2653
# Epoch 8/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.2882 - val_loss: 0.2210
# Epoch 9/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.2390 - val_loss: 0.2039
# Epoch 10/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.2223 - val_loss: 0.1745
# Epoch 11/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.1786 - val_loss: 0.1292
# Epoch 12/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.1303 - val_loss: 0.0847
# Epoch 13/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0826 - val_loss: 0.0498
# Epoch 14/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.0467 - val_loss: 0.0263
# Epoch 15/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.0251 - val_loss: 0.0185
# Epoch 16/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 0.0221 - val_loss: 0.0293
# Epoch 17/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0386 - val_loss: 0.0330
# Epoch 18/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.0418 - val_loss: 0.0243
# Epoch 19/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - loss: 0.0297 - val_loss: 0.0174
# Epoch 20/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.0200 - val_loss: 0.0150
# Epoch 21/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0157 - val_loss: 0.0165
# Epoch 22/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 0.0154 - val_loss: 0.0192
# Epoch 23/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.0178 - val_loss: 0.0207
# Epoch 24/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0191 - val_loss: 0.0203
# Epoch 25/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 0.0182 - val_loss: 0.0186
# Epoch 26/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0166 - val_loss: 0.0167
# Epoch 27/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0163 - val_loss: 0.0154
# Epoch 28/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0151 - val_loss: 0.0146
# Epoch 29/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0147 - val_loss: 0.0142
# Epoch 30/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0152 - val_loss: 0.0138
# Epoch 31/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0151 - val_loss: 0.0135
# Epoch 32/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0149 - val_loss: 0.0133
# Epoch 33/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0142 - val_loss: 0.0132
# Epoch 34/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0143 - val_loss: 0.0133
# Epoch 35/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0139 - val_loss: 0.0135
# Epoch 36/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0137 - val_loss: 0.0135
# Epoch 37/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0133 - val_loss: 0.0134
# Epoch 38/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0131 - val_loss: 0.0132
# Epoch 39/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.0137 - val_loss: 0.0130
# Epoch 40/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0127 - val_loss: 0.0127
# Epoch 41/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0125 - val_loss: 0.0125
# Epoch 42/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0121 - val_loss: 0.0124
# Epoch 43/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0124 - val_loss: 0.0124
# Epoch 44/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0123 - val_loss: 0.0122
# Epoch 45/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0118 - val_loss: 0.0120
# Epoch 46/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.0116 - val_loss: 0.0119
# Epoch 47/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0122 - val_loss: 0.0118
# Epoch 48/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0118 - val_loss: 0.0117
# Epoch 49/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0115 - val_loss: 0.0118
# Epoch 50/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0115 - val_loss: 0.0119
# Epoch 51/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0118 - val_loss: 0.0120
# Epoch 52/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0117 - val_loss: 0.0119
# Epoch 53/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0116 - val_loss: 0.0117
# Epoch 54/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0115 - val_loss: 0.0112
# Epoch 55/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0112 - val_loss: 0.0110
# Epoch 56/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0111 - val_loss: 0.0110
# Epoch 57/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0113 - val_loss: 0.0112
# Epoch 58/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.0110 - val_loss: 0.0112
# Epoch 59/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0110 - val_loss: 0.0111
# Epoch 60/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0114 - val_loss: 0.0110
# Epoch 61/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0112 - val_loss: 0.0109
# Epoch 62/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0116 - val_loss: 0.0108
# Epoch 63/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0110 - val_loss: 0.0109
# Epoch 64/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0112 - val_loss: 0.0109
# Epoch 65/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0111 - val_loss: 0.0107
# Epoch 66/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0114 - val_loss: 0.0107
# Epoch 67/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0115 - val_loss: 0.0106
# Epoch 68/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0108 - val_loss: 0.0107
# Epoch 69/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0109 - val_loss: 0.0109
# Epoch 70/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0113 - val_loss: 0.0110
# Epoch 71/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0109 - val_loss: 0.0108
# Epoch 72/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0114 - val_loss: 0.0107
# Epoch 73/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0111 - val_loss: 0.0107
# Epoch 74/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0107 - val_loss: 0.0108
# Epoch 75/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0110 - val_loss: 0.0110
# Epoch 76/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0110 - val_loss: 0.0109
# Epoch 77/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0104 - val_loss: 0.0108
# Epoch 78/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0108 - val_loss: 0.0108
# Epoch 79/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.0111 - val_loss: 0.0108
# Epoch 80/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0103 - val_loss: 0.0108
# Epoch 81/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0107 - val_loss: 0.0108
# Epoch 82/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 0.0108 - val_loss: 0.0107
# Epoch 83/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0107 - val_loss: 0.0106
# Epoch 84/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0107 - val_loss: 0.0106
# Epoch 85/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.0107 - val_loss: 0.0108
# Epoch 86/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 87/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0104 - val_loss: 0.0108
# Epoch 88/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 89/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0105 - val_loss: 0.0108
# Epoch 90/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0105 - val_loss: 0.0106
# Epoch 91/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 0.0105 - val_loss: 0.0104
# Epoch 92/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0105 - val_loss: 0.0104
# Epoch 93/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0107 - val_loss: 0.0106
# Epoch 94/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0106 - val_loss: 0.0107
# Epoch 95/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0.0106 - val_loss: 0.0107
# Epoch 96/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0106 - val_loss: 0.0107
# Epoch 97/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0107 - val_loss: 0.0106
# Epoch 98/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0107 - val_loss: 0.0105
# Epoch 99/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.0109 - val_loss: 0.0105
# Epoch 100/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 0.0109 - val_loss: 0.0105
# Epoch 101/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 102/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 103/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 104/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.0105 - val_loss: 0.0107
# Epoch 105/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0107 - val_loss: 0.0104
# Epoch 106/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.0099 - val_loss: 0.0104
# Epoch 107/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 0.0101 - val_loss: 0.0104
# Epoch 108/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0106 - val_loss: 0.0103
# Epoch 109/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0106 - val_loss: 0.0105
# Epoch 110/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0103 - val_loss: 0.0108
# Epoch 111/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 0.0103 - val_loss: 0.0110
# Epoch 112/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0102 - val_loss: 0.0109
# Epoch 113/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0100 - val_loss: 0.0106
# Epoch 114/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0106 - val_loss: 0.0104
# Epoch 115/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0104 - val_loss: 0.0104
# Epoch 116/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0100 - val_loss: 0.0104
# Epoch 117/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0104 - val_loss: 0.0105
# Epoch 118/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0106 - val_loss: 0.0105
# Epoch 119/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0102 - val_loss: 0.0104
# Epoch 120/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0103 - val_loss: 0.0103
# Epoch 121/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0106 - val_loss: 0.0104
# Epoch 122/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0105 - val_loss: 0.0105
# Epoch 123/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0105 - val_loss: 0.0103
# Epoch 124/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0102 - val_loss: 0.0102
# Epoch 125/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0105 - val_loss: 0.0102
# Epoch 126/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0101 - val_loss: 0.0104
# Epoch 127/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 128/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0102 - val_loss: 0.0106
# Epoch 129/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0105 - val_loss: 0.0105
# Epoch 130/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0107 - val_loss: 0.0103
# Epoch 131/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0103 - val_loss: 0.0102
# Epoch 132/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0104 - val_loss: 0.0102
# Epoch 133/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.0104 - val_loss: 0.0102
# Epoch 134/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.0101 - val_loss: 0.0101
# Epoch 135/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 0.0105 - val_loss: 0.0102
# Epoch 136/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0104 - val_loss: 0.0104
# Epoch 137/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.0101 - val_loss: 0.0104
# Epoch 138/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0102 - val_loss: 0.0104
# Epoch 139/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0098 - val_loss: 0.0102
# Epoch 140/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0101 - val_loss: 0.0100
# Epoch 141/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0097 - val_loss: 0.0100
# Epoch 142/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.0100 - val_loss: 0.0102
# Epoch 143/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 0.0100 - val_loss: 0.0102
# Epoch 144/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0105 - val_loss: 0.0105
# Epoch 145/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.0104 - val_loss: 0.0106
# Epoch 146/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0105 - val_loss: 0.0105
# Epoch 147/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.0101 - val_loss: 0.0103
# Epoch 148/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0103 - val_loss: 0.0102
# Epoch 149/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0103 - val_loss: 0.0102
# Epoch 150/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0106 - val_loss: 0.0101
# Epoch 151/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0102 - val_loss: 0.0100
# Epoch 152/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0094 - val_loss: 0.0101
# Epoch 153/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0097 - val_loss: 0.0102
# Epoch 154/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0097 - val_loss: 0.0102
# Epoch 155/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0096 - val_loss: 0.0102
# Epoch 156/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0103 - val_loss: 0.0102
# Epoch 157/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0099 - val_loss: 0.0102
# Epoch 158/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 0.0096 - val_loss: 0.0102
# Epoch 159/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0102 - val_loss: 0.0101
# Epoch 160/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0101 - val_loss: 0.0101
# Epoch 161/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0101 - val_loss: 0.0101
# Epoch 162/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0096 - val_loss: 0.0102
# Epoch 163/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0102 - val_loss: 0.0102
# Epoch 164/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 0.0103 - val_loss: 0.0101
# Epoch 165/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 0.0100 - val_loss: 0.0102
# Epoch 166/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 0.0103 - val_loss: 0.0102
# Epoch 167/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.0101 - val_loss: 0.0100
# Epoch 168/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 0.0096 - val_loss: 0.0099
# Epoch 169/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.0101 - val_loss: 0.0099
# Epoch 170/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0097 - val_loss: 0.0100
# Epoch 171/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.0099 - val_loss: 0.0101
# Epoch 172/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - loss: 0.0100 - val_loss: 0.0102
# Epoch 173/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - loss: 0.0098 - val_loss: 0.0102
# Epoch 174/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - loss: 0.0103 - val_loss: 0.0104
# Epoch 175/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0101 - val_loss: 0.0102
# Epoch 176/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0100 - val_loss: 0.0100
# Epoch 177/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0100 - val_loss: 0.0099
# Epoch 178/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0099 - val_loss: 0.0098
# Epoch 179/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0099 - val_loss: 0.0098
# Epoch 180/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0101 - val_loss: 0.0100
# Epoch 181/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0096 - val_loss: 0.0101
# Epoch 182/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 0.0097 - val_loss: 0.0099
# Epoch 183/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0099 - val_loss: 0.0098
# Epoch 184/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0099 - val_loss: 0.0099
# Epoch 185/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0097 - val_loss: 0.0101
# Epoch 186/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.0099 - val_loss: 0.0101
# Epoch 187/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.0099 - val_loss: 0.0098
# Epoch 188/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0099 - val_loss: 0.0096
# Epoch 189/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0095 - val_loss: 0.0097
# Epoch 190/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0095 - val_loss: 0.0100
# Epoch 191/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0095 - val_loss: 0.0104
# Epoch 192/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0095 - val_loss: 0.0102
# Epoch 193/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0096 - val_loss: 0.0100
# Epoch 194/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0099 - val_loss: 0.0098
# Epoch 195/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0098 - val_loss: 0.0098
# Epoch 196/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 197/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0094 - val_loss: 0.0099
# Epoch 198/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.0096 - val_loss: 0.0100
# Epoch 199/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0094 - val_loss: 0.0100
# Epoch 200/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0100 - val_loss: 0.0099

# %%
# Plot training & validation loss values
plt.rcParams.update({
    'font.size': 20,         # Base font size
    'axes.titlesize': 28,    # Title font size
    'axes.labelsize': 20,    # Axis label font size
    'xtick.labelsize': 20,   # X-axis tick font size
    'ytick.labelsize': 20,   # Y-axis tick font size
    'legend.fontsize': 20,   # Legend font size
    'figure.figsize': (8, 7),   # Default figure size
    'axes.grid': True,          # Enable grid by default
    'lines.linewidth': 2,       # Line thickness
    'lines.markersize': 6       # Marker size if used
})

plt.figure(figsize=(8, 7))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Mean Squared Error')
plt.xlabel('Epoch')
plt.ylim(0, 0.05)  # Set y-axis from 0 to 0.05
plt.legend()
plt.grid(True)
plt.show()

# %%
# Make predictions
yM_pred = modelM.predict(XM_test)
yM_pred_Tesla = yM_pred[:, Target_IDX]

# Correlation coefficient
corr_matrix = np.corrcoef(yM_test[:, Target_IDX], yM_pred_Tesla.flatten())

# Convert to a pandas DataFrame with labeled rows and columns
df_corr = pd.DataFrame(
    corr_matrix,
    index=["True value", "Predicted value"],
    columns=["True value", "Predicted value"]
)

print(df_corr)

# Plot actual vs predicted values

plt.scatter(yM_test[:, Target_IDX], yM_pred_Tesla, s=10, label='Predictions')
plt.plot([min(yM_test[:, Target_IDX]), max(yM_test[:, Target_IDX])],
         [min(yM_test[:, Target_IDX]), max(yM_test[:, Target_IDX])],
         'r--', label='y = x')  # Red dashed line
plt.xlabel("True Value")
plt.ylabel("Predicted Value")
plt.legend()
plt.grid(True)
plt.title("Actual vs Predicted")
plt.show()

from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(yM_test[:, Target_IDX], yM_pred_Tesla)

print(f"Mean Absolue Error (MAE): {mae:.4f}")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#                  True value  Predicted value
# True value         1.000000         0.994924
# Predicted value    0.994924         1.000000
# Mean Absolue Error (MAE): 0.0679

# %%
# trading simulation
Init_cap = 1000000 # initial capital is 1 million dollars.
St_volM = [0] # index 0: initial stock volume, index 1: stock volume after the 1st day trading ...
balanceM = [Init_cap] # index 0: initial balance, index 1: balance after the 1st day trading ...
St_predM = np.array(yM_future_Unscale[0:1])
NetAssetM = [Init_cap]

for i in range(XM_future.shape[0]):
  y_pred_scaled = modelM.predict(XM_future[i:i+1], verbose=0)
  y_pred_unscaled = scalerM.inverse_transform(y_pred_scaled)
  St_predM=np.vstack([St_predM,y_pred_unscaled]) # X_future[i:i+1]: slicing X_future between i-th row and i+1-th row, not including i+1-th row.
  if St_predM[i+1,Target_IDX]>yM_future_Unscale[i,Target_IDX]:
    St_change = balanceM[i]//yM_future_Unscale[i,Target_IDX] # quotient of a division
    Rem_balance = balanceM[i]%yM_future_Unscale[i,Target_IDX] # remainder of a division
    St_volM.append(St_volM[i]+St_change)
    balanceM.append(Rem_balance)
    NetAssetM.append(balanceM[i+1]+St_volM[i+1]*yM_future_Unscale[i,Target_IDX])
  else:
    balanceM.append(balanceM[i]+St_volM[i]*yM_future_Unscale[i,Target_IDX])
    St_volM.append(0)
    NetAssetM.append(balanceM[i+1]+St_volM[i+1]*yM_future_Unscale[i,Target_IDX])

# %%
print("Total profit or loss =", NetAssetM[-1])

# First plot
plt.figure()
plt.scatter(range(len(balanceM)), balanceM, s=10)
plt.title("Balance")
plt.xlabel("Days")
plt.ylabel("Balance")
plt.grid(True)

# Second plot
plt.figure()
plt.scatter(range(len(St_volM)), St_volM, s=10)
plt.title("Stock volume")
plt.xlabel("Days")
plt.ylabel("Stock volume")
plt.grid(True)

# Third plot
plt.figure()
plt.scatter(range(len(NetAssetM)), NetAssetM, s=10)
plt.title("Net Asset")
plt.xlabel("Days")
plt.ylabel("Net asset, $")
plt.grid(True)

# Fourth plot
plt.figure()
plt.scatter(St_predM[:, Target_IDX], yM_future_Unscale[:, Target_IDX], s=10)

# Get the min and max range for the diagonal line
min_val = min(St_predM[:, Target_IDX].min(), yM_future_Unscale[:, Target_IDX].min())
max_val = max(St_predM[:, Target_IDX].max(), yM_future_Unscale[:, Target_IDX].max())

# Plot y = x line
plt.plot([min_val, max_val], [min_val, max_val], 'r--', label='y = x')

plt.xlabel("Predicted, $")
plt.ylabel("True, $")
plt.legend()
plt.grid(True)
plt.show()

# Make predictions

# Correlation coefficient
corr_matrix = np.corrcoef(St_predM[:, Target_IDX], yM_future_Unscale[:, Target_IDX])

# Convert to a pandas DataFrame with labeled rows and columns
df_corr = pd.DataFrame(
    corr_matrix,
    index=["True value", "Predicted value"],
    columns=["True value", "Predicted value"]
)

print(df_corr)

mae = mean_absolute_error(yM_future_Unscale[:, Target_IDX], St_predM[:, Target_IDX])

print(f"Mean Absolute Error (MSE): {mae:.4f}")
# Out:
# Total profit or loss = 745932.7899999998
#                  True value  Predicted value
# True value         1.000000         0.962289
# Predicted value    0.962289         1.000000
# Mean Absolute Error (MSE): 8.7341

# %%
# trading simulation
Init_cap = 1000000 # initial capital is 1 million dollars.
St_volM = [0] # index 0: initial stock volume, index 1: stock volume after the 1st day trading ...
balanceM = [Init_cap] # index 0: initial balance, index 1: balance after the 1st day trading ...
St_predM = np.array(yM_future_Unscale[0:1])
NetAssetM = [Init_cap]

Lim_up = 1.015

for i in range(XM_future.shape[0]):
  y_pred_scaled = modelM.predict(XM_future[i:i+1], verbose=0)
  y_pred_unscaled = scalerM.inverse_transform(y_pred_scaled)
  St_predM=np.vstack([St_predM,y_pred_unscaled]) # X_future[i:i+1]: slicing X_future between i-th row and i+1-th row, not including i+1-th row.
  if St_predM[i+1,Target_IDX]>yM_future_Unscale[i,Target_IDX]*Lim_up:
    St_change = balanceM[i]//yM_future_Unscale[i,Target_IDX] # quotient of a division
    Rem_balance = balanceM[i]%yM_future_Unscale[i,Target_IDX] # remainder of a division
    St_volM.append(St_volM[i]+St_change)
    balanceM.append(Rem_balance)
    NetAssetM.append(balanceM[i+1]+St_volM[i+1]*yM_future_Unscale[i,Target_IDX])
  else:
    balanceM.append(balanceM[i]+St_volM[i]*yM_future_Unscale[i,Target_IDX])
    St_volM.append(0)
    NetAssetM.append(balanceM[i+1]+St_volM[i+1]*yM_future_Unscale[i,Target_IDX])

# %%
# Third plot
plt.figure()
plt.scatter(range(len(NetAssetM)), NetAssetM, s=10)
plt.title("Net Asset")
plt.xlabel("Days")
plt.ylabel("Net asset, $")
plt.grid(True)

print("Total profit or loss =", NetAssetM[-1])

# Fourth plot
plt.figure()
plt.scatter(St_predM[:, Target_IDX], yM_future_Unscale[:, Target_IDX], s=10)

# Get the min and max range for the diagonal line
min_val = min(St_predM[:, Target_IDX].min(), yM_future_Unscale[:, Target_IDX].min())
max_val = max(St_predM[:, Target_IDX].max(), yM_future_Unscale[:, Target_IDX].max())

# Plot y = x line
plt.plot([min_val, max_val], [min_val, max_val], 'r--', label='y = x')

plt.xlabel("Predicted, $")
plt.ylabel("True, $")
plt.legend()
plt.grid(True)
plt.show()

plt.show()
# Out:
# Total profit or loss = 891256.5799999996

# %%
# trading simulation
Init_cap = 1000000 # initial capital is 1 million dollars.
St_volM = [0] # index 0: initial stock volume, index 1: stock volume after the 1st day trading ...
balanceM = [Init_cap] # index 0: initial balance, index 1: balance after the 1st day trading ...
St_predM = np.array(yM_future_Unscale[0:1])
NetAssetM = [Init_cap]

Lim_up = 1.03

for i in range(XM_future.shape[0]):
  y_pred_scaled = modelM.predict(XM_future[i:i+1], verbose=0)
  y_pred_unscaled = scalerM.inverse_transform(y_pred_scaled)
  St_predM=np.vstack([St_predM,y_pred_unscaled]) # X_future[i:i+1]: slicing X_future between i-th row and i+1-th row, not including i+1-th row.
  if St_predM[i+1,Target_IDX]>yM_future_Unscale[i,Target_IDX]*Lim_up:
    St_change = balanceM[i]//yM_future_Unscale[i,Target_IDX] # quotient of a division
    Rem_balance = balanceM[i]%yM_future_Unscale[i,Target_IDX] # remainder of a division
    St_volM.append(St_volM[i]+St_change)
    balanceM.append(Rem_balance)
    NetAssetM.append(balanceM[i+1]+St_volM[i+1]*yM_future_Unscale[i,Target_IDX])
  else:
    balanceM.append(balanceM[i]+St_volM[i]*yM_future_Unscale[i,Target_IDX])
    St_volM.append(0)
    NetAssetM.append(balanceM[i+1]+St_volM[i+1]*yM_future_Unscale[i,Target_IDX])

# %%
# Third plot
plt.figure()
plt.scatter(range(len(NetAssetM)), NetAssetM, s=10)
plt.title("Net Asset")
plt.xlabel("Days")
plt.ylabel("Net asset, $")
plt.grid(True)

print("Total profit or loss =", NetAssetM[-1])

# Fourth plot
plt.figure()
plt.scatter(St_predM[:, Target_IDX], yM_future_Unscale[:, Target_IDX], s=10)

# Get the min and max range for the diagonal line
min_val = min(St_predM[:, Target_IDX].min(), yM_future_Unscale[:, Target_IDX].min())
max_val = max(St_predM[:, Target_IDX].max(), yM_future_Unscale[:, Target_IDX].max())

# Plot y = x line
plt.plot([min_val, max_val], [min_val, max_val], 'r--', label='y = x')

plt.xlabel("Predicted, $")
plt.ylabel("True, $")
plt.legend()
plt.grid(True)
plt.show()

plt.show()
# Out:
# Total profit or loss = 1274642.8499999996
