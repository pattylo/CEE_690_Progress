# %%
import numpy as np
import pandas as pd
import pylab
import seaborn as sns

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.pyplot import subplots
import statsmodels.api as sm
from statsmodels.formula.api import logit

# %matplotlib inline

np.set_printoptions(precision=5, suppress= True)

from google.colab import drive
drive.mount('/content/drive/',force_remount=True)
mydir = "/content/drive/My Drive/Courses/25_1st_Statistical Learning/HW/"
# !ls "/content/drive/My Drive/Courses/25_1st_Statistical Learning/HW/"
# Out:
# Mounted at /content/drive/
#  Auto.csv		     'Mod_stock(Bitcoin).csv'
#  BirdCancer.csv		      Mod_stock.csv
#  cars.csv		     'Mod_stock(gold).csv'
# 'Commodity10(Beef).csv'      'Mod_US Stock Market Dataset_2.csv'
# 'Commodity10(Crudeoil).csv'  'Mod_US Stock Market Dataset.csv'
# 'Commodity2_10(Beef).csv'     NYSE.csv
# 'Commodity(Crudeoil).csv'     pendigits.tra
#  FEV.csv		      Pima.csv
#  Hitters1.csv		      Prob4-2.csv
#  Hw1.ipynb		      Project_Stock_Diff.ipynb
#  HW1_SS.ipynb		      Project_Stock.ipynb
#  HW2_SS.ipynb		      Project_Stock_MA_useless.ipynb
#  HW3_SS.ipynb		      Project_Stock_Mult.ipynb
#  HW4_SS.ipynb		      Project_Stock_MV.ipynb
#  HW5_SS.ipynb		      Project_Stock_original.ipynb
#  HW6_SS.ipynb		      Project_Stock_Univ_bias.ipynb
#  HW7_2_SS.ipynb		      Project_Stock_Univ.ipynb
#  HW7_SS.ipynb		      Sev_temp4.csv
#  HW8_SS.ipynb		     'US Stock Market Dataset.csv'
# 'Mod_stock2_100(tesla).csv'   Xdata.pkl
# 'Mod_stock7(Tesla).csv'       ydata.pkl

# %% [markdown]
# # RNN_multivariate (stock)

# %%
# multivariate only using Tesla stock and filtered Crude_oil

St_data_ori = pd.read_csv(mydir + 'Mod_US Stock Market Dataset_2.csv')
St_data = St_data_ori[::-1].reset_index(drop=True)
dataM_raw = St_data.drop(['No','Date'], axis=1).astype('float64')
print(dataM_raw)
dataM_raw = dataM_raw[['Tesla','S&P_500']]  #bad: , good:  ,'Crude_oil'(loss: 0.0070 - val_loss: 0.0297),'S&P_500'(loss: 0.0079 - val_loss: 0.0100),'Gold'(loss: 0.0232 - val_loss: 0.0309), Not tested: ,
Target_IDX = 0

dataM_Unscale = dataM_raw.to_numpy()
# since each variable is on its own scale, it's a good idea to scale them first

from sklearn.preprocessing import StandardScaler
scalerM = StandardScaler()
dataM = scalerM.fit_transform(dataM_raw)
Start_Time = 0
Cur_Time = 517
Size_data = dataM.shape[1]

# autocorrelation function for the data
#from statsmodels.graphics.tsaplots import plot_acf

#fig, ax = plt.subplots(figsize=(10, 5))
#plot_acf(dataM_past, lags=300, ax=ax, title='Autocorrelation Function') # lags: number of lags to show

#plt.xlabel('Lag')
#plt.ylabel('Autocorrelation')
#plt.show()
# Out:
#      Natural_Gas  Natural_Gas_Vol.  Crude_oil  Crude_oil_Vol.  Copper  \
# 0          2.122          164570.0      61.18        486870.0  2.8250
# 1          2.130          144670.0      63.05        885860.0  2.7870
# 2          2.135          154680.0      63.27        724240.0  2.7900
# 3          2.162          163010.0      62.70        582650.0  2.7935
# 4          2.141          242560.0      59.61       1210000.0  2.8120
# ..           ...               ...        ...             ...     ...
# 713        6.779           73120.0      80.95        269620.0  3.6165
# 714        7.308           59050.0      77.94        379150.0  3.6200
# 715        7.024           35510.0      76.28        266450.0  3.6330
# 716        6.712            3650.0      77.24        405030.0  3.6165
# 717        7.235          101680.0      78.20        381870.0  3.6395
#
#      Copper_Vol.  Bitcoin  Bitcoin_Vol.  Ethereum  Ethereum_Vol.  ...  \
# 0        72460.0   6967.0      632780.0    127.19     11450000.0  ...
# 1        74750.0   7343.0      936290.0    134.27     15670000.0  ...
# 2        59570.0   7759.0      786750.0    144.08     14360000.0  ...
# 3        59470.0   8156.0     1010000.0    143.04     13580000.0  ...
# 4        77700.0   8060.0     1190000.0    140.81     13710000.0  ...
# ..           ...      ...           ...       ...            ...  ...
# 713        250.0  16213.0      287210.0   1139.74       815180.0  ...
# 714        210.0  16624.0      305080.0   1185.79       688960.0  ...
# 715        180.0  16512.0      204070.0   1198.12       426960.0  ...
# 716        460.0  16212.0      284840.0   1167.73       518170.0  ...
# 717      55240.0  16440.0      271580.0   1216.55       549930.0  ...
#
#      Berkshire  Berkshire_Vol.  Netflix  Netflix_Vol.  Amazon  Amazon_Vol.  \
# 0     342261.0           410.0   329.81     4350000.0   94.90   80720000.0
# 1     339155.0           220.0   325.90     3800000.0   93.75   75330000.0
# 2     340210.0           280.0   335.83     5670000.0   95.14   81310000.0
# 3     338901.0           280.0   330.75     4740000.0   95.34   82680000.0
# 4     339188.0           190.0   339.26     7110000.0   94.60   70240000.0
# ..         ...             ...      ...           ...     ...          ...
# 713   476980.0          2820.0   286.69     6250000.0   93.20   62190000.0
# 714   477020.0          2920.0   291.50     5920000.0   94.13   59410000.0
# 715   478676.0          2660.0   285.54     3240000.0   93.41   35090000.0
# 716   472712.0          4030.0   281.17     4710000.0   93.95   75060000.0
# 717   475843.0          2640.0   280.96     5790000.0   92.42   65570000.0
#
#        Meta   Meta_Vol.    Gold  Gold_Vol.
# 0    209.78  12090000.0  1528.1   270550.0
# 1    208.67  11200000.0  1552.4   436740.0
# 2    212.60  17070000.0  1568.8   558970.0
# 3    213.06  15110000.0  1574.3   435870.0
# 4    215.22  13490000.0  1560.2   813410.0
# ..      ...         ...     ...        ...
# 713  111.44  29030000.0  1739.9   153090.0
# 714  112.24  21340000.0  1745.6   167770.0
# 715  111.41  12010000.0  1754.0   134300.0
# 716  108.78  23300000.0  1740.3   132770.0
# 717  109.46  23900000.0  1763.7   127320.0
#
# [718 rows x 35 columns]

# %%
# Create sequences for training
TIME_STEPS = 50
def create_sequences(dataM, time_steps):
    XM, yM = [], []
    for i in range(len(dataM) - time_steps):
        XM.append(dataM[i:i + time_steps])
        yM.append(dataM[i + time_steps])
    return np.array(XM), np.array(yM)

XM, yM = create_sequences(dataM, TIME_STEPS)

XM_past = XM[Start_Time:Cur_Time,:].reshape(-1, TIME_STEPS, Size_data)
yM_past = yM[Start_Time:Cur_Time,:]
XM_future = XM[Cur_Time+1:,:].reshape(-1, TIME_STEPS, Size_data)
yM_future = yM[Cur_Time:,:]

print(XM_past)

XM_Unscale, yM_Unscale = create_sequences(dataM_Unscale, TIME_STEPS)

XM_past_Unscale = XM_Unscale[Start_Time:Cur_Time,:].reshape(-1, TIME_STEPS, Size_data)
yM_past_Unscale = yM_Unscale[Start_Time:Cur_Time,:]
XM_future_Unscale = XM_Unscale[Cur_Time+1:,:].reshape(-1, TIME_STEPS, Size_data)
yM_future_Unscale = yM_Unscale[Cur_Time:,:]
# Out:
# [[[-0.22319 -0.90859]
#   [-0.14905 -0.90486]
#   [-0.14033 -0.90252]
#   ...
#   [-1.34123 -1.02253]
#   [-1.39991 -1.03981]
#   [-1.39079 -1.02674]]
#
#  [[-0.14905 -0.90486]
#   [-0.14033 -0.90252]
#   [-0.16293 -0.88991]
#   ...
#   [-1.39991 -1.03981]
#   [-1.39079 -1.02674]
#   [-1.51092 -1.05195]]
#
#  [[-0.14033 -0.90252]
#   [-0.16293 -0.88991]
#   [-0.28544 -0.89972]
#   ...
#   [-1.39079 -1.02674]
#   [-1.51092 -1.05195]
#   [-1.5803  -1.09211]]
#
#  ...
#
#  [[ 0.84806  0.31907]
#   [ 0.85044  0.6693 ]
#   [ 0.93013  0.38305]
#   ...
#   [ 1.08951  1.20258]
#   [ 1.33968  1.21986]
#   [ 1.4844   1.36789]]
#
#  [[ 0.85044  0.6693 ]
#   [ 0.93013  0.38305]
#   [ 1.01101  0.23548]
#   ...
#   [ 1.33968  1.21986]
#   [ 1.4844   1.36789]
#   [ 1.59144  1.50938]]
#
#  [[ 0.93013  0.38305]
#   [ 1.01101  0.23548]
#   [ 0.97176  0.07671]
#   ...
#   [ 1.4844   1.36789]
#   [ 1.59144  1.50938]
#   [ 1.6414   1.75221]]]

# %%
from sklearn.model_selection import train_test_split

XM_train, XM_test, yM_train, yM_test = train_test_split(XM_past, yM_past, random_state=111, test_size = 0.3) # random_state i is a fixed seed value that ensures the random operations (like data shuffling) produce the same result every time.

print(XM_train.shape)

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
# Out:
# (361, 50, 2)

# %%
modelM = Sequential([
    SimpleRNN(50, activation='relu', return_sequences=False),
    Dense(Size_data)  # Output layer for regression (predicting 3 values at once?)
])

modelM.compile(optimizer='adam', loss='mse')
history = modelM.fit(XM_train, yM_train, epochs=200, batch_size=256, validation_data=(XM_test, yM_test))
# Out:
# Epoch 1/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - loss: 0.7298 - val_loss: 0.7079
# Epoch 2/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 0.6771 - val_loss: 0.6416
# Epoch 3/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.5942 - val_loss: 0.5844
# Epoch 4/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 0.5475 - val_loss: 0.5334
# Epoch 5/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.5011 - val_loss: 0.4856
# Epoch 6/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.4456 - val_loss: 0.4395
# Epoch 7/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.3983 - val_loss: 0.3935
# Epoch 8/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.3629 - val_loss: 0.3475
# Epoch 9/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.3101 - val_loss: 0.3013
# Epoch 10/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 0.2668 - val_loss: 0.2553
# Epoch 11/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.2176 - val_loss: 0.2100
# Epoch 12/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.1775 - val_loss: 0.1660
# Epoch 13/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.1295 - val_loss: 0.1258
# Epoch 14/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0976 - val_loss: 0.0962
# Epoch 15/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0707 - val_loss: 0.0892
# Epoch 16/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0698 - val_loss: 0.0938
# Epoch 17/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0721 - val_loss: 0.0839
# Epoch 18/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0596 - val_loss: 0.0687
# Epoch 19/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0480 - val_loss: 0.0587
# Epoch 20/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0386 - val_loss: 0.0533
# Epoch 21/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0322 - val_loss: 0.0494
# Epoch 22/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0301 - val_loss: 0.0438
# Epoch 23/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.
# Epoch 120/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0069 - val_loss: 0.0254
# Epoch 121/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0070 - val_loss: 0.0253
# Epoch 122/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0070 - val_loss: 0.0254
# Epoch 123/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0067 - val_loss: 0.0253
# Epoch 124/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0070 - val_loss: 0.0251
# Epoch 125/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0069 - val_loss: 0.0252
# Epoch 126/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0068 - val_loss: 0.0253
# Epoch 127/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0068 - val_loss: 0.0253
# Epoch 128/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0069 - val_loss: 0.0254
# Epoch 129/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0067 - val_loss: 0.0255
# Epoch 130/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0070 - val_loss: 0.0253
# Epoch 131/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0067 - val_loss: 0.0251
# Epoch 132/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0069 - val_loss: 0.0252
# Epoch 133/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0066 - val_loss: 0.0250
# Epoch 134/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0067 - val_loss: 0.0248
# Epoch 135/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0068 - val_loss: 0.0251
# Epoch 136/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0066 - val_loss: 0.0255
# Epoch 137/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0069 - val_loss: 0.0253
# Epoch 138/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0066 - val_loss: 0.0252
# Epoch 139/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0066 - val_loss: 0.0253
# Epoch 140/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0064 - val_loss: 0.0253
# Epoch 141/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0066 - val_loss: 0.0248
# Epoch 142/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0066 - val_loss: 0.0247
# Epoch 143/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0065 - val_loss: 0.0252
# Epoch 144/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0066 - val_loss: 0.0251
# Epoch 145/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0065 - val_loss: 0.0252
# Epoch 146/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0067 - val_loss: 0.0257
# Epoch 147/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0067 - val_loss: 0.0257
# Epoch 148/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0067 - val_loss: 0.0252
# Epoch 149/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0065 - val_loss: 0.0249
# Epoch 150/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0062 - val_loss: 0.0248
# Epoch 151/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0064 - val_loss: 0.0247
# Epoch 152/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0065 - val_loss: 0.0249
# Epoch 153/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0063 - val_loss: 0.0252
# Epoch 154/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0063 - val_loss: 0.0252
# Epoch 155/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0063 - val_loss: 0.0249
# Epoch 156/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0065 - val_loss: 0.0249
# Epoch 157/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0063 - val_loss: 0.0252
# Epoch 158/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0063 - val_loss: 0.0251
# Epoch 159/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0063 - val_loss: 0.0250
# Epoch 160/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0062 - val_loss: 0.0250
# Epoch 161/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0062 - val_loss: 0.0250
# Epoch 162/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0063 - val_loss: 0.0250
# Epoch 163/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0063 - val_loss: 0.0252
# Epoch 164/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0064 - val_loss: 0.0251
# Epoch 165/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0061 - val_loss: 0.0248
# Epoch 166/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0062 - val_loss: 0.0248
# Epoch 167/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0063 - val_loss: 0.0251
# Epoch 168/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0065 - val_loss: 0.0253
# Epoch 169/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0060 - val_loss: 0.0251
# Epoch 170/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0063 - val_loss: 0.0251
# Epoch 171/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0061 - val_loss: 0.0251
# Epoch 172/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0062 - val_loss: 0.0246
# Epoch 173/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0062 - val_loss: 0.0245
# Epoch 174/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0060 - val_loss: 0.0249
# Epoch 175/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0060 - val_loss: 0.0253
# Epoch 176/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0062 - val_loss: 0.0251
# Epoch 177/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0059 - val_loss: 0.0248
# Epoch 178/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0060 - val_loss: 0.0248
# Epoch 179/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0061 - val_loss: 0.0247
# Epoch 180/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0061 - val_loss: 0.0250
# Epoch 181/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0062 - val_loss: 0.0254
# Epoch 182/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0062 - val_loss: 0.0251
# Epoch 183/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0062 - val_loss: 0.0249
# Epoch 184/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0059 - val_loss: 0.0249
# Epoch 185/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0059 - val_loss: 0.0249
# Epoch 186/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0059 - val_loss: 0.0248
# Epoch 187/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0061 - val_loss: 0.0248
# Epoch 188/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0062 - val_loss: 0.0250
# Epoch 189/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0061 - val_loss: 0.0250
# Epoch 190/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0059 - val_loss: 0.0249
# Epoch 191/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0061 - val_loss: 0.0250
# Epoch 192/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0057 - val_loss: 0.0251
# Epoch 193/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0059 - val_loss: 0.0246
# Epoch 194/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0059 - val_loss: 0.0248
# Epoch 195/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.0058 - val_loss: 0.0254
# Epoch 196/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0058 - val_loss: 0.0251
# Epoch 197/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 0.0058 - val_loss: 0.0248
# Epoch 198/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 0.0061 - val_loss: 0.0249
# Epoch 199/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0057 - val_loss: 0.0253
# Epoch 200/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0057 - val_loss: 0.0246

# %%
# Plot training & validation loss values
plt.rcParams.update({
    'font.size': 20,         # Base font size
    'axes.titlesize': 28,    # Title font size
    'axes.labelsize': 20,    # Axis label font size
    'xtick.labelsize': 20,   # X-axis tick font size
    'ytick.labelsize': 20,   # Y-axis tick font size
    'legend.fontsize': 20,   # Legend font size
    'figure.figsize': (8, 7),   # Default figure size
    'axes.grid': True,          # Enable grid by default
    'lines.linewidth': 2,       # Line thickness
    'lines.markersize': 6       # Marker size if used
})

plt.figure(figsize=(8, 7))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Mean Squared Error')
plt.xlabel('Epoch')
plt.ylim(0, 0.05)  # Set y-axis from 0 to 0.05
plt.legend()
plt.grid(True)
plt.show()

# %%
# Make predictions
yM_pred = modelM.predict(XM_test)
yM_pred_Tesla = yM_pred[:, Target_IDX]

# Correlation coefficient
corr_matrix = np.corrcoef(yM_test[:, Target_IDX], yM_pred_Tesla.flatten())

# Convert to a pandas DataFrame with labeled rows and columns
df_corr = pd.DataFrame(
    corr_matrix,
    index=["True value", "Predicted value"],
    columns=["True value", "Predicted value"]
)

print(df_corr)

# Plot actual vs predicted values

plt.scatter(yM_test[:, Target_IDX], yM_pred_Tesla, s=10, label='Predictions')
plt.plot([min(yM_test[:, Target_IDX]), max(yM_test[:, Target_IDX])],
         [min(yM_test[:, Target_IDX]), max(yM_test[:, Target_IDX])],
         'r--', label='y = x')  # Red dashed line
plt.xlabel("True Value")
plt.ylabel("Predicted Value")
plt.legend()
plt.grid(True)
plt.title("Actual vs Predicted")
plt.show()

from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(yM_test[:, Target_IDX], yM_pred_Tesla)

print(f"Mean Absolue Error (MAE): {mae:.4f}")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step
#                  True value  Predicted value
# True value         1.000000         0.976017
# Predicted value    0.976017         1.000000
# Mean Absolue Error (MAE): 0.0771

# %%
# trading simulation
Init_cap = 1000000 # initial capital is 1 million dollars.
St_volM = [0] # index 0: initial stock volume, index 1: stock volume after the 1st day trading ...
balanceM = [Init_cap] # index 0: initial balance, index 1: balance after the 1st day trading ...
St_predM = np.array(yM_future_Unscale[0:1])
NetAssetM = [Init_cap]

for i in range(XM_future.shape[0]):
  y_pred_scaled = modelM.predict(XM_future[i:i+1], verbose=0)
  y_pred_unscaled = scalerM.inverse_transform(y_pred_scaled)
  St_predM=np.vstack([St_predM,y_pred_unscaled]) # X_future[i:i+1]: slicing X_future between i-th row and i+1-th row, not including i+1-th row.
  if St_predM[i+1,Target_IDX]>yM_future_Unscale[i,Target_IDX]:
    St_change = balanceM[i]//yM_future_Unscale[i,Target_IDX] # quotient of a division
    Rem_balance = balanceM[i]%yM_future_Unscale[i,Target_IDX] # remainder of a division
    St_volM.append(St_volM[i]+St_change)
    balanceM.append(Rem_balance)
    NetAssetM.append(balanceM[i+1]+St_volM[i+1]*yM_future_Unscale[i,Target_IDX])
  else:
    balanceM.append(balanceM[i]+St_volM[i]*yM_future_Unscale[i,Target_IDX])
    St_volM.append(0)
    NetAssetM.append(balanceM[i+1]+St_volM[i+1]*yM_future_Unscale[i,Target_IDX])

# %%
print("Total profit or loss =", NetAssetM[-1])


# First plot
plt.figure()
plt.scatter(range(len(balanceM)), balanceM, s=10)
plt.title("Balance")
plt.xlabel("Days")
plt.ylabel("Balance")
plt.grid(True)

# Second plot
plt.figure()
plt.scatter(range(len(St_volM)), St_volM, s=10)
plt.title("Stock volume")
plt.xlabel("Days")
plt.ylabel("Stock volume")
plt.grid(True)

# Third plot
plt.figure()
plt.scatter(range(len(NetAssetM)), NetAssetM, s=10)
plt.title("Net Asset")
plt.xlabel("Days")
plt.ylabel("Net asset, $")
plt.grid(True)

# Fourth plot
plt.figure()
plt.scatter(St_predM[:, Target_IDX], yM_future_Unscale[:, Target_IDX], s=10)

# Get the min and max range for the diagonal line
min_val = min(St_predM[:, Target_IDX].min(), yM_future_Unscale[:, Target_IDX].min())
max_val = max(St_predM[:, Target_IDX].max(), yM_future_Unscale[:, Target_IDX].max())

# Plot y = x line
plt.plot([min_val, max_val], [min_val, max_val], 'r--', label='y = x')

plt.xlabel("Predicted, $")
plt.ylabel("True, $")
plt.legend()
plt.grid(True)
plt.show()

# Make predictions

# Correlation coefficient
corr_matrix = np.corrcoef(St_predM[:, Target_IDX], yM_future_Unscale[:, Target_IDX])

# Convert to a pandas DataFrame with labeled rows and columns
df_corr = pd.DataFrame(
    corr_matrix,
    index=["True value", "Predicted value"],
    columns=["True value", "Predicted value"]
)

print(df_corr)

mae = mean_absolute_error(yM_future_Unscale[:, Target_IDX], St_predM[:, Target_IDX])

print(f"Mean Absolute Error (MSE): {mae:.4f}")
# Out:
# Total profit or loss = 915908.8
#                  True value  Predicted value
# True value         1.000000         0.941807
# Predicted value    0.941807         1.000000
# Mean Absolute Error (MSE): 3.6262

# %%
# trading simulation
Init_cap = 1000000 # initial capital is 1 million dollars.
St_volM = [0] # index 0: initial stock volume, index 1: stock volume after the 1st day trading ...
balanceM = [Init_cap] # index 0: initial balance, index 1: balance after the 1st day trading ...
St_predM = np.array(yM_future_Unscale[0:1])
NetAssetM = [Init_cap]

Lim_up = 1.015

for i in range(XM_future.shape[0]):
  y_pred_scaled = modelM.predict(XM_future[i:i+1], verbose=0)
  y_pred_unscaled = scalerM.inverse_transform(y_pred_scaled)
  St_predM=np.vstack([St_predM,y_pred_unscaled]) # X_future[i:i+1]: slicing X_future between i-th row and i+1-th row, not including i+1-th row.
  if St_predM[i+1,Target_IDX]>yM_future_Unscale[i,Target_IDX]*Lim_up:
    St_change = balanceM[i]//yM_future_Unscale[i,Target_IDX] # quotient of a division
    Rem_balance = balanceM[i]%yM_future_Unscale[i,Target_IDX] # remainder of a division
    St_volM.append(St_volM[i]+St_change)
    balanceM.append(Rem_balance)
    NetAssetM.append(balanceM[i+1]+St_volM[i+1]*yM_future_Unscale[i,Target_IDX])
  else:
    balanceM.append(balanceM[i]+St_volM[i]*yM_future_Unscale[i,Target_IDX])
    St_volM.append(0)
    NetAssetM.append(balanceM[i+1]+St_volM[i+1]*yM_future_Unscale[i,Target_IDX])

# %%
print("Total profit or loss =", NetAssetM[-1])


# Third plot
plt.figure()
plt.scatter(range(len(NetAssetM)), NetAssetM, s=10)
plt.title("Net Asset")
plt.xlabel("Days")
plt.ylabel("Net asset, $")
plt.grid(True)

# Fourth plot
plt.figure()
plt.scatter(St_predM[:, Target_IDX], yM_future_Unscale[:, Target_IDX], s=10)

# Get the min and max range for the diagonal line
min_val = min(St_predM[:, Target_IDX].min(), yM_future_Unscale[:, Target_IDX].min())
max_val = max(St_predM[:, Target_IDX].max(), yM_future_Unscale[:, Target_IDX].max())

# Plot y = x line
plt.plot([min_val, max_val], [min_val, max_val], 'r--', label='y = x')

plt.xlabel("Predicted, $")
plt.ylabel("True, $")
plt.legend()
plt.grid(True)
plt.show()

plt.show()
# Out:
# Total profit or loss = 937035.7100000001

# %%
# trading simulation
Init_cap = 1000000 # initial capital is 1 million dollars.
St_volM = [0] # index 0: initial stock volume, index 1: stock volume after the 1st day trading ...
balanceM = [Init_cap] # index 0: initial balance, index 1: balance after the 1st day trading ...
St_predM = np.array(yM_future_Unscale[0:1])
NetAssetM = [Init_cap]

Lim_up = 1.03

for i in range(XM_future.shape[0]):
  y_pred_scaled = modelM.predict(XM_future[i:i+1], verbose=0)
  y_pred_unscaled = scalerM.inverse_transform(y_pred_scaled)
  St_predM=np.vstack([St_predM,y_pred_unscaled]) # X_future[i:i+1]: slicing X_future between i-th row and i+1-th row, not including i+1-th row.
  if St_predM[i+1,Target_IDX]>yM_future_Unscale[i,Target_IDX]*Lim_up:
    St_change = balanceM[i]//yM_future_Unscale[i,Target_IDX] # quotient of a division
    Rem_balance = balanceM[i]%yM_future_Unscale[i,Target_IDX] # remainder of a division
    St_volM.append(St_volM[i]+St_change)
    balanceM.append(Rem_balance)
    NetAssetM.append(balanceM[i+1]+St_volM[i+1]*yM_future_Unscale[i,Target_IDX])
  else:
    balanceM.append(balanceM[i]+St_volM[i]*yM_future_Unscale[i,Target_IDX])
    St_volM.append(0)
    NetAssetM.append(balanceM[i+1]+St_volM[i+1]*yM_future_Unscale[i,Target_IDX])

# %%
# Third plot
plt.figure()
plt.scatter(range(len(NetAssetM)), NetAssetM, s=10)
plt.title("Net Asset")
plt.xlabel("Days")
plt.ylabel("Net asset, $")
plt.grid(True)

print("Total profit or loss =", NetAssetM[-1])

# Fourth plot
plt.figure()
plt.scatter(St_predM[:, Target_IDX], yM_future_Unscale[:, Target_IDX], s=10)

# Get the min and max range for the diagonal line
min_val = min(St_predM[:, Target_IDX].min(), yM_future_Unscale[:, Target_IDX].min())
max_val = max(St_predM[:, Target_IDX].max(), yM_future_Unscale[:, Target_IDX].max())

# Plot y = x line
plt.plot([min_val, max_val], [min_val, max_val], 'r--', label='y = x')

plt.xlabel("Predicted, $")
plt.ylabel("True, $")
plt.legend()
plt.grid(True)
plt.show()


mae = mean_absolute_error(yM_future_Unscale[:, Target_IDX], St_predM[:, Target_IDX])

print(f"Mean Absolute Error (MSE): {mae:.4f}")
# Out:
# Total profit or loss = 924740.6299999998
# Mean Absolute Error (MSE): 3.6262

# %%
# trading simulation
Init_cap = 1000000 # initial capital is 1 million dollars.
St_volM = [0] # index 0: initial stock volume, index 1: stock volume after the 1st day trading ...
balanceM = [Init_cap] # index 0: initial balance, index 1: balance after the 1st day trading ...
St_predM = np.array(yM_future_Unscale[0:1])
NetAssetM = [Init_cap]
Lim_up = 1.03
current_mae = 0
bias_list = [0]
signed_diff = []

def moving_average(arr, window_size):
    if len(arr) < window_size:
        return np.mean(arr)
    return np.mean(arr[-window_size:])


for i in range(XM_future.shape[0]):
  y_pred_scaled = modelM.predict(XM_future[i:i+1], verbose=0)
  y_pred_unscaled = scalerM.inverse_transform(y_pred_scaled)
  St_predM=np.vstack([St_predM,y_pred_unscaled]) # X_future[i:i+1]: slicing X_future between i-th row and i+1-th row, not including i+1-th row.
  # Compute running MAE up to current step
  # Signed error series up to current time
  signed_diff = St_predM[:i+1, Target_IDX] - yM_future_Unscale[:i+1, Target_IDX]
  # Moving average filtered bias
  mean_signed_diff = moving_average(signed_diff, window_size=10)
  bias_list.append(mean_signed_diff)
  if St_predM[i+1,Target_IDX]-mean_signed_diff>yM_future_Unscale[i,Target_IDX]*Lim_up:
    St_change = balanceM[i]//yM_future_Unscale[i,Target_IDX] # quotient of a division
    Rem_balance = balanceM[i]%yM_future_Unscale[i,Target_IDX] # remainder of a division
    St_volM.append(St_volM[i]+St_change)
    balanceM.append(Rem_balance)
    NetAssetM.append(balanceM[i+1]+St_volM[i+1]*yM_future_Unscale[i,Target_IDX])
  else:
    balanceM.append(balanceM[i]+St_volM[i]*yM_future_Unscale[i,Target_IDX])
    St_volM.append(0)
    NetAssetM.append(balanceM[i+1]+St_volM[i+1]*yM_future_Unscale[i,Target_IDX])

# %%
# First plot
plt.figure()
plt.scatter(range(len(balanceM)), balanceM, s=10)
plt.title("Balance")
plt.xlabel("Days")
plt.ylabel("Balance")
plt.grid(True)

# Third plot
plt.figure()
plt.scatter(range(len(NetAssetM)), NetAssetM, s=10)
plt.title("Net Asset")
plt.xlabel("Days")
plt.ylabel("Net asset, $")
plt.grid(True)

print("Total profit or loss =", NetAssetM[-1])

# Fourth plot
plt.figure()
plt.scatter(St_predM[:, Target_IDX]-bias_list, yM_future_Unscale[:, Target_IDX], s=10)

# Get the min and max range for the diagonal line
min_val = min(St_predM[:, Target_IDX].min(), yM_future_Unscale[:, Target_IDX].min())
max_val = max(St_predM[:, Target_IDX].max(), yM_future_Unscale[:, Target_IDX].max())

# Plot y = x line
plt.plot([min_val, max_val], [min_val, max_val], 'r--', label='y = x')

plt.xlabel("Predicted, $")
plt.ylabel("True, $")
plt.legend()
plt.grid(True)
plt.show()

# Correlation coefficient
corr_matrix = np.corrcoef(St_predM[:, Target_IDX]-bias_list, yM_future_Unscale[:, Target_IDX])

# Convert to a pandas DataFrame with labeled rows and columns
df_corr = pd.DataFrame(
    corr_matrix,
    index=["True value", "Predicted value"],
    columns=["True value", "Predicted value"]
)

print(df_corr)

mae = mean_absolute_error(yM_future_Unscale[:, Target_IDX], St_predM[:, Target_IDX]-bias_list)

print(f"Mean Absolute Error (MSE): {mae:.4f}")

plt.figure()
plt.plot(St_predM[0:25, Target_IDX],label="pred")
plt.plot(yM_future_Unscale[0:25, Target_IDX])
plt.legend()

print(St_predM[:, Target_IDX])
print(yM_future_Unscale[:, Target_IDX])

print([St_predM[0:25, Target_IDX],yM_future_Unscale[0:25, Target_IDX]])
# Out:
# Total profit or loss = 1025977.2900000003
#                  True value  Predicted value
# True value         1.000000         0.959793
# Predicted value    0.959793         1.000000
# Mean Absolute Error (MSE): 2.7657
# [102.75    100.34304  99.53219  98.73213  98.7221   98.97578 100.02818
#  100.09127 102.0212  102.36539 101.93032 103.49622 104.91182 104.61884
#  102.71633  99.60481 100.15111 102.51598 105.10043 108.7724  109.56496
#  108.0519  108.03654 108.47009 109.14838 108.14429 108.44106 109.66698
#  110.7486  111.81295 112.49232 113.91789 115.303   114.59475 115.37003
